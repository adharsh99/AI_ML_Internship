# %%
import os

model_exists = os.path.exists(
    "../models/job_matching_model.pkl"
)

print("Model File Exists:", model_exists)
# Out:
# Model File Exists: True

# %%
model_data = {
    "model": model,
    "vectorizer": vectorizer
}

model_path = "../models/job_matching_model.pkl"

with open(model_path, "wb") as file:
    pickle.dump(model_data, file)

print("Model saved successfully!")
print("Model Location:", model_path)
# Out:
# Model saved successfully!
# Model Location: ../models/job_matching_model.pkl

# %%
test_cases = [
    "python django fastapi git",
    "python pandas numpy sql power bi",
    "python machine learning scikit-learn pandas",
    "html css javascript react django",
    "python deep learning machine learning fastapi"
]

for skills in test_cases:

    vectorized = vectorizer.transform([skills])

    prediction = model.predict(vectorized)

    print("Skills:", skills)
    print("Predicted Role:", prediction[0])
    print("-" * 50)
# Out:
# Skills: python django fastapi git
# Predicted Role: Python Developer
# --------------------------------------------------
# Skills: python pandas numpy sql power bi
# Predicted Role: Data Analyst
# --------------------------------------------------
# Skills: python machine learning scikit-learn pandas
# Predicted Role: Machine Learning Engineer
# --------------------------------------------------
# Skills: html css javascript react django
# Predicted Role: Full Stack Developer
# --------------------------------------------------
# Skills: python deep learning machine learning fastapi
# Predicted Role: AI Engineer
# --------------------------------------------------

# %%
test_skills = "python sql pandas numpy git"

test_vectorized = vectorizer.transform(
    [test_skills]
)

prediction = model.predict(test_vectorized)

print("Test Skills:", test_skills)
print("Predicted Job Role:", prediction[0])
# Out:
# Test Skills: python sql pandas numpy git
# Predicted Job Role: Data Analyst

# %%
model = LogisticRegression()

model.fit(X_vectorized, y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
vectorizer = TfidfVectorizer()

X_vectorized = vectorizer.fit_transform(X)

print("TF-IDF Vectorization Completed!")
print("Original Shape:", X.shape)
print("Vectorized Shape:", X_vectorized.shape)
# Out:
# TF-IDF Vectorization Completed!
# Original Shape: (5,)
# Vectorized Shape: (5, 21)

# %%
X = df["skills"]
y = df["job_role"]

print("Features:")
print(X)

print("\nTarget:")
print(y)
# Out:
# Features:
# 0               python sql django fastapi git rest api
# 1               python sql pandas numpy excel power bi
# 2    python machine learning scikit-learn numpy pan...
# 3          python html css javascript react django git
# 4    python machine learning deep learning git fastapi
# Name: skills, dtype: str
#
# Target:
# 0             Python Developer
# 1                 Data Analyst
# 2    Machine Learning Engineer
# 3         Full Stack Developer
# 4                  AI Engineer
# Name: job_role, dtype: str

# %%
print("Dataset Shape:", df.shape)

print("\nJob Roles:")
print(df["job_role"].unique())
# Out:
# Dataset Shape: (5, 2)
#
# Job Roles:
# <StringArray>
# [         'Python Developer',              'Data Analyst',
#  'Machine Learning Engineer',      'Full Stack Developer',
#                'AI Engineer']
# Length: 5, dtype: str

# %%
data = {
    "skills": [
        "python sql django fastapi git rest api",
        "python sql pandas numpy excel power bi",
        "python machine learning scikit-learn numpy pandas git",
        "python html css javascript react django git",
        "python machine learning deep learning git fastapi"
    ],

    "job_role": [
        "Python Developer",
        "Data Analyst",
        "Machine Learning Engineer",
        "Full Stack Developer",
        "AI Engineer"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#                                               skills  \
# 0             python sql django fastapi git rest api
# 1             python sql pandas numpy excel power bi
# 2  python machine learning scikit-learn numpy pan...
# 3        python html css javascript react django git
# 4  python machine learning deep learning git fastapi
#
#                     job_role
# 0           Python Developer
# 1               Data Analyst
# 2  Machine Learning Engineer
# 3       Full Stack Developer
# 4                AI Engineer

# %%
# %pip install pandas scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\dell\appdata\roaming\python\python312\site-packages (3.0.5)
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2026.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl (8.2 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python312\python.exe

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python312\python.exe

# %%
import pandas as pd
import pickle
import os

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!
